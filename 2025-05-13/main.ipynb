# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Cars82.csv").sample(n=50, random_state=48)
display(df)
# Out:
#      Manufacturer           Model     Type  Min.Price  Price  Max.Price  \
# 9        Cadillac         DeVille    Large       33.0   34.7       36.3
# 40        Hyundai          Scoupe   Sporty        9.1   10.0       11.0
# 55     Mitsubishi        Diamante  Midsize       22.4   26.1       29.9
# 62       Plymouth           Laser   Sporty       11.4   14.4       17.4
# 38        Hyundai           Excel    Small        6.8    8.0        9.2
# 8           Buick         Riviera  Midsize       26.3   26.3       26.3
# 75         Toyota          Celica   Sporty       14.2   18.4       22.6
# 4             BMW            535i  Midsize       23.7   30.0       36.2
# 56         Nissan          Sentra    Small        8.7   11.8       14.9
# 59     Oldsmobile         Achieva  Compact       13.0   13.5       14.0
# 5           Buick         Century  Midsize       14.2   15.7       17.3
# 20          Dodge          Shadow    Small        8.4   11.3       14.2
# ...

# %%
display(df.describe())
# Out:
#        Min.Price      Price  Max.Price   MPG.city  MPG.highway  Cylinders  \
# count   50.00000  50.000000  50.000000  50.000000    50.000000  50.000000
# mean    16.27600  18.520000  20.766000  23.560000    30.440000   4.740000
# std      8.30794   8.778592   9.548279   6.273234     5.635746   1.242282
# min      6.70000   7.400000   7.900000  16.000000    23.000000   3.000000
# 25%      9.02500  11.500000  14.050000  19.000000    27.000000   4.000000
# 50%     14.10000  15.850000  18.350000  22.500000    29.000000   4.000000
# 75%     22.25000  25.275000  25.950000  25.000000    33.000000   6.000000
# max     37.50000  40.100000  44.600000  46.000000    50.000000   8.000000
#
#        EngineSize  Horsepower          RPM  Rev.per.mile  Fuel.tank.capacity  \
# count   50.000000   50.000000    50.000000     50.000000           50.000000
# mean     2.502000  138.400000  5378.000000   2420.900000           15.910000
# ...

# %%
df[df[("Origin"=="USA")&("Cylinders"==4)]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\willi\miniconda3\envs\icd\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: False
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df[df[("Origin"=="USA")&("Cylinders"==4)]]
#
# ...
