# %%
import pandas as pd
import scipy
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv(r'C:\Users\willi\github\aed\2025-04-08\dad600_acad3.csv')

# %%
df.shape
# Out:
# (600, 11)

# %%
df = df.sample(n=100,random_state=48)

# %%
df.shape
# Out:
# (100, 11)

# %%
for i in df.columns:
    sns.histplot(data=df[i])
    plt.title(i)
    plt.show()

# %%
df["IMC"] = df["Peso"]/df["Altura"]**2

# %%
(df.head())
# Out:
#      Idade     E.Civil P.Treino  Freq.Sem Aval.Instal  Aval.Aparelhos  \
# 547     41  divorciado    tarde         5           r               3
# 522     35      casado    noite         3           A               5
# 449     33    solteiro    manha         4          Ar               4
# 407     42      casado    noite         3           A               5
# 131     38  divorciado    tarde         1           r               3
#
#      Aval.Prof  Val.Mensal P.Troca.Acad  Peso  Altura        IMC
# 547          3         136          sim    67    1.67  24.023809
# 522          4         114          nao    65    1.63  24.464602
# 449          5         104          sim    66    1.61  25.461981
# 407          4         139          nao    65    1.68  23.030045
# 131          3         136          sim    68    1.65  24.977043

# %%
q1 = np.quantile(df['IMC'],0.25)
q2 = np.quantile(df['IMC'],0.50)
q3 = np.quantile(df['IMC'],0.75)
print(f"Q1: {q1}\nQ2: {q2}\nQ3: {q3}")
# Out:
# Q1: 22.48280345587616
# Q2: 23.58353785710827
# Q3: 25.345694193966505

# %%
# Out:
# 'Q122.48280345587616\nQ223.58353785710827\nQ325.345694193966505'
